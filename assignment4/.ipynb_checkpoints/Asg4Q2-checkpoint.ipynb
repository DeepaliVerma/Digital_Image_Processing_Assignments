# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
im = cv2.imread('./images/kidney.jpg',0);
bin_kidney = np.uint8(im > 128)
plt.imshow(bin_kidney,cmap = cm.gray)

# %%
open_ellipse = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (16, 16))
close_ellipse = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))

# Opening
kidney_open = cv2.erode(bin_kidney,open_ellipse)
kidney_open = cv2.dilate(kidney_open,open_ellipse)

# Closing
kidney_close = cv2.dilate(kidney_open,close_ellipse)
kidney_close = cv2.erode(kidney_open,close_ellipse)

plt.imshow(kidney_close,cmap=cm.gray)

# %%
labelled = label(kidney_close)
color_labels = label2rgb(labelled, image=kidney_close, colors=['black', 'lime', 'purple', 'blue', 'red', 'orange', 'pink', 'green', 'lightblue', 'yellow', 'lightgreen'])
